# %% [markdown]
# # TP Lasso & Ridge - Régression

# %%
#importer vos libs 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso, Ridge
from sklearn.preprocessing import StandardScaler

import warnings
warnings.simplefilter("ignore")

df = pd.read_csv("../data/houseData.csv")
print("Dimensions du dataset:", df.shape)
# Out:
# Dimensions du dataset: (21613, 21)

# %%
columns_to_drop = ['id', 'date', 'waterfront', 'view']
df = df.drop(columns_to_drop, axis = 1)
print("Nouvelles dimensions:", df.shape)
# Out:
# Nouvelles dimensions: (21613, 17)

# %%
sns.pairplot(df[['price', 'bedrooms', 'bathrooms', 'sqft_living']])
plt.show()

# %%
y = df['price'].values
print("Taille du vecteur cible :", len(y))
# Out:
# Taille du vecteur cible : 21613

# %%
X = df.drop('price', axis = 1)
print("\nColonnes utilisées pour la prédiction:")
print(X.columns.tolist())
# Out:
# Colonnes utilisées pour la prédiction:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

# %%
lasso = Lasso(
    alpha=0.2,
)
lasso.fit(X, y)
# Out:
# Lasso(alpha=0.2)

# %%
print("Coefficients avec alpha=0.2:")
print(lasso.coef_)
# Out:
# Coefficients avec alpha=0.2:
# [-4.60759488e+04  4.30360839e+04  2.84242942e+02  1.58200409e-01
#   1.10269916e+04  2.92314998e+04  1.01098077e+05 -9.69653208e+01
#  -1.04900337e+02 -2.83156609e+03  3.49026743e+01 -4.78262713e+02
#   5.55905746e+05 -2.51997308e+05  4.02912555e+01 -3.26986765e-01]

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(len(lasso.coef_)), lasso.coef_, 'bo-', linewidth=2, markersize=8)
plt.xticks(range(len(X.columns)), X.columns, rotation=45)
plt.grid(True)
plt.title('Coefficients Lasso avec alpha=0.2')
plt.ylabel('Valeur des coefficients')
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)  # Ligne à y=0
plt.tight_layout()
plt.show()

# %%
lasso_2 = Lasso(alpha=10)
lasso_2.fit(X, y)
print("\nCoefficients avec alpha=1:")
print(lasso_2.coef_)
# Out:
# Coefficients avec alpha=1:
# [-4.60566224e+04  4.30041359e+04  2.84236109e+02  1.57886913e-01
#   1.10149786e+04  2.91953623e+04  1.01126995e+05 -9.69675286e+01
#  -1.04849476e+02 -2.83284393e+03  3.48927348e+01 -4.76885592e+02
#   5.55288774e+05 -2.51092958e+05  4.02663543e+01 -3.27545860e-01]

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(len(lasso_2.coef_)), lasso_2.coef_, 'go-', linewidth=2, markersize=8)
plt.xticks(range(len(X.columns)), X.columns, rotation=45)
plt.grid(True)
plt.title('Coefficients Lasso avec alpha=1')
plt.ylabel('Valeur des coefficients')
plt.axhline(y=0, color='r', linestyle='--', alpha=0.1)
plt.tight_layout()
plt.show()

# %%
lasso_3 = Lasso(alpha=1000)
lasso_3.fit(X, y)
print("\nCoefficients avec alpha=1000:")
print(lasso_3.coef_)
# Out:
# Coefficients avec alpha=1000:
# [-4.41042683e+04  3.97767416e+04  2.83545742e+02  1.26217388e-01
#   9.80142646e+03  2.55447293e+04  1.04048376e+05 -9.71905697e+01
#  -9.97114186e+01 -2.96193238e+03  3.38886490e+01 -3.37768304e+02
#   4.92962011e+05 -1.59735108e+05  3.77508225e+01 -3.84025860e-01]

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(len(lasso_3.coef_)), lasso_3.coef_, 'ro-', linewidth=2, markersize=8)
plt.xticks(range(len(X.columns)), X.columns, rotation=45)
plt.grid(True)
plt.title('Coefficients Lasso avec alpha=1000')
plt.ylabel('Valeur des coefficients')
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
